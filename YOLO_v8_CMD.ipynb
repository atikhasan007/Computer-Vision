# %% [markdown]
# <a href="https://colab.research.google.com/github/atikhasan007/Computer-Vision/blob/main/YOLO_v8_CMD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Modes:
#
# train, val, predict
#
# #Tasks:
#
# detect, segment, classify
#
# #Data:
#
# Format can be differ for task type, Supports data.yaml, data_folder, data_name

# %% [markdown]
# # Installation

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## CMD

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 1. Detection:

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/images.jpg"
# Out:
# Ultralytics 8.4.39 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/images.jpg: 480x640 3 persons, 1 car, 67.2ms
# Speed: 4.0ms preprocess, 67.2ms inference, 17.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict-2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 2. Segmentation:

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="/content/images.jpg"
# Out:
# Ultralytics 8.4.39 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,404,320 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1 /content/images.jpg: 480x640 2 persons, 3 cars, 63.7ms
# Speed: 4.0ms preprocess, 63.7ms inference, 63.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## Python Script

# %%
from ultralytics import YOLO

# Load a segmentation model
model = YOLO("yolov8n-seg.pt")
model.predict(source="/content/images.jpg")
# Out:
# image 1/1 /content/images.jpg: 480x640 2 persons, 3 cars, 58.9ms
# Speed: 4.0ms preprocess, 58.9ms inference, 29.6ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %% [markdown]
# # 3. Classification:

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="/content/images.jpg"
# Out:
# ...
# Ultralytics 8.4.39 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-cls summary (fused): 30 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# image 1/1 /content/images.jpg: 224x224 leatherback_turtle 0.32, Indian_cobra 0.13, kelpie 0.08, Staffordshire_bullterrier 0.02, loggerhead 0.02, 2.8ms
# Speed: 17.2ms preprocess, 2.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
